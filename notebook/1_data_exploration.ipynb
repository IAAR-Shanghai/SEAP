# %%
# notebooks/1_data_exploration.ipynb

import os
import pandas as pd

# %%
# Define paths
train_data_dir = '../data/processed/train'
test_data_dir = '../data/processed/test'

# List all processed datasets
train_files = os.listdir(train_data_dir)
test_files = os.listdir(test_data_dir)

print("Train files:", train_files)
print("Test files:", test_files)
# Out:
# Train files: ['winogrande_train_processed.parquet', 'obqa_train_processed.parquet', 'wikitext2_train_processed.parquet', 'gsm8k_train_processed.parquet', 'ai2_arc_train_processed.parquet', 'hellaswag_train_processed.parquet', 'boolq_train_processed.parquet', 'piqa_train_processed.parquet']
# Test files: ['boolq_test_processed.parquet', 'wikitext2_test_processed.parquet', 'hellaswag_test_processed.parquet', 'piqa_test_processed.parquet', 'winogrande_test_processed.parquet', 'gsm8k_test_processed.parquet', 'obqa_test_processed.parquet', 'ai2_arc_test_processed.parquet']

# %%
# Load a sample dataset (can explore others based on task)
sample_train_df = pd.read_parquet(os.path.join(train_data_dir, 'obqa_train_processed.parquet'))
sample_test_df = pd.read_parquet(os.path.join(test_data_dir, 'obqa_test_processed.parquet'))

# %%
sample_train_df
# Out:
#      task_type                                              input label  \
# 0         obqa  Question: The sun is responsible for\nOptions:...     D
# 1         obqa  Question: When standing miles away from Mount ...     D
# 2         obqa  Question: When food is reduced in the stomach\...     C
# 3         obqa  Question: Stars are\nOptions:\nA) warm lights ...     C
# 4         obqa  Question: You can make a telescope with a\nOpt...     D
# ...        ...                                                ...   ...
# 4952      obqa  Question: A bulldozer alters the area of\nOpti...     A
# 4953      obqa  Question: An organism that can survive without...     A
# 4954      obqa  Question: The nimbleness of this animal is a k...     B
# 4955      obqa  Question: Birds will have different kinds of b...     A
# 4956      obqa  Question: Harriet wants to know the area of a ...     A
#
#                                                    gold  \
# 0                plants sprouting, blooming and wilting
# 1        the mountains seem smaller than in photographs
# 2                     nutrients are being deconstructed
# 3     great balls of gas burning billions of miles away
# 4                                          mailing tube
# ...                                                 ...
# 4952                                        skyscrapers
# 4953                                     Brewer's yeast
# 4954                                       the antelope
# 4955                                organisms they hunt
# 4956                                            a ruler
#
#                                         input_with_gold  \
# 0     Question: The sun is responsible for\nOptions:...
# 1     Question: When standing miles away from Mount ...
# 2     Question: When food is reduced in the stomach\...
# 3     Question: Stars are\nOptions:\nA) warm lights ...
# 4     Question: You can make a telescope with a\nOpt...
# ...                                                 ...
# 4952  Question: A bulldozer alters the area of\nOpti...
# 4953  Question: An organism that can survive without...
# 4954  Question: The nimbleness of this animal is a k...
# 4955  Question: Birds will have different kinds of b...
# 4956  Question: Harriet wants to know the area of a ...
#
#                                                  corpus
# 0     The sun is the source of energy for physical c...
# 1     As distance to an object increases , that obje...
# 2     Digestion is when stomach acid breaks down foo...
# 3     A star is made of gases. Stars are great balls...
# 4     Galileo galilei made improvements to the teles...
# ...                                                 ...
# 4952  Breaking down an object changes that object 's...
# 4953  A single-cell organism can survive without the...
# 4954  Adaptation is when an organism develops a trai...
# 4955  A beak is used for catching prey by some birds...
# 4956  A ruler is used for measuring the length of an...
#
# [4957 rows x 6 columns]

# %%
# View the first few rows of the dataset
print(sample_train_df.head(10))
# Out:
#   task_type                                              input label  \
# 0      obqa  Question: The sun is responsible for\nOptions:...     D
# 1      obqa  Question: When standing miles away from Mount ...     D
# 2      obqa  Question: When food is reduced in the stomach\...     C
# 3      obqa  Question: Stars are\nOptions:\nA) warm lights ...     C
# 4      obqa  Question: You can make a telescope with a\nOpt...     D
# 5      obqa  Question: Poison causes harm to which of the f...     A
# 6      obqa  Question: an inherited characteristic found on...     D
# 7      obqa  Question: What doesn't eliminate waste?\nOptio...     D
# 8      obqa  Question: As a car approaches you in the night...     A
# 9      obqa  Question: When the weather changes as it does ...     D
#
#                                                 gold  \
# 0             plants sprouting, blooming and wilting
# 1     the mountains seem smaller than in photographs
# 2                  nutrients are being deconstructed
# 3  great balls of gas burning billions of miles away
# 4                                       mailing tube
# 5                                             a Tree
# 6                                                fur
# 7                                             robots
# 8                 the headlights become more intense
# 9                                the ground may warm
#
#                                      input_with_gold  \
# 0  Question: The sun is responsible for\nOptions:...
# 1  Question: When standing miles away from Mount ...
# 2  Question: When food is reduced in the stomach\...
# 3  Question: Stars are\nOptions:\nA) warm lights ...
# 4  Question: You can make a telescope with a\nOpt...
# 5  Question: Poison causes harm to which of the f...
# 6  Question: an inherited characteristic found on...
# 7  Question: What doesn't eliminate waste?\nOptio...
# 8  Question: As a car approaches you in the night...
# 9  Question: When the weather changes as it does ...
#
#                                               corpus
# 0  The sun is the source of energy for physical c...
# 1  As distance to an object increases , that obje...
# 2  Digestion is when stomach acid breaks down foo...
# 3  A star is made of gases. Stars are great balls...
# 4  Galileo galilei made improvements to the teles...
# 5  Poison causes harm to living things. Poison ca...
# 6  The colors of the parts of an organism are inh...
# 7  All living things eliminate waste. What doesn'...
# 8  As a source of light becomes closer , that sou...
# 9  Seasons cause change to the environment. When ...

# %%
# Check data types and missing values for each column
print(sample_train_df.info())
print(sample_test_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4957 entries, 0 to 4956
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   task_type        4957 non-null   object
#  1   input            4957 non-null   object
#  2   label            4957 non-null   object
#  3   gold             4957 non-null   object
#  4   input_with_gold  4957 non-null   object
#  5   corpus           4957 non-null   object
# dtypes: object(6)
# memory usage: 232.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   task_type        500 non-null    object
#  1   input            500 non-null    object
#  2   label            500 non-null    object
#  3   gold             500 non-null    object
#  4   input_with_gold  500 non-null    object
#  5   corpus           500 non-null    object
# dtypes: object(6)
# memory usage: 23.6+ KB
# None
