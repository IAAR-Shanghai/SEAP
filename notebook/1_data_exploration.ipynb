# %%
# notebooks/1_data_exploration.ipynb

import os
import pandas as pd

# %%
# Define paths
root_data_dir = '../data/processed'

# %%
# Load a sample dataset (can explore others based on task)
tasks_data_df = pd.read_parquet(os.path.join(root_data_dir, 'final_with_prompts.parquet'))

# %%
# View the first few rows of the dataset
tasks_data_df.head(3)
# Out:
#   task_type      task_format  \
# 0     arc_c  multiple_choice
# 1     arc_c  multiple_choice
# 2     arc_c  multiple_choice
#
#                                             question label  \
# 0  The day before the class is going to do a lab ...     B
# 1  Which mixture contains ingredients that can be...     B
# 2  In 2005, a team of scientists discovered a pho...     B
#
#                                         gold  \
# 0          to prevent injury to toes or feet
# 1                                fruit salad
# 2  The hydrothermal vent emits usable light.
#
#                                               corpus  \
# 0  The day before the class is going to do a lab ...
# 1  Which mixture contains ingredients that can be...
# 2  In 2005, a team of scientists discovered a pho...
#
#                                            rationale  \
# 0  Explanation:  \nThe teacher's instruction not ...
# 1  Explanation:  \nTo determine which mixture con...
# ...

# %%
# Check data types and missing values for each column
print(tasks_data_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3235 entries, 0 to 3234
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   task_type         3235 non-null   object
#  1   task_format       3235 non-null   object
#  2   question          3235 non-null   object
#  3   label             3235 non-null   object
#  4   gold              3235 non-null   object
#  5   corpus            3235 non-null   object
#  6   rationale         3235 non-null   object
#  7   knowledge         3235 non-null   object
#  8   split             3235 non-null   object
#  9   prompt_zero_shot  3235 non-null   object
#  10  prompt_cot        3235 non-null   object
#  11  prompt_icl        3235 non-null   object
#  12  prompt_icl_cot    3235 non-null   object
# dtypes: object(13)
# memory usage: 328.7+ KB
# None

# %%
# View the first few rows of the dataset
tasks_data_df[tasks_data_df['task_type']=='piqa'].head(3)
# Out:
#     task_type      task_format  \
# 512      piqa  multiple_choice
# 513      piqa  multiple_choice
# 514      piqa  multiple_choice
#
#                                               question label  \
# 512  To remove a dandelion from the ground, you can...     A
# 513  How to Make a Snowy Paper Christmas Tree\nOpti...     A
# 514  What if I have a pimple that is too painful to...     B
#
#                                                   gold  \
# 512             Use your fingers to pick the dandelion
# 513  You can make a Snowy Paper Christmas Tree by f...
# 514  Place the pimple under hot water for 10 min. t...
#
#                                                 corpus  \
# 512  To remove a dandelion from the ground, you can...
# 513  How to Make a Snowy Paper Christmas Tree You c...
# 514  What if I have a pimple that is too painful to...
#
#                                              rationale  \
# 512  Explanation:  \nTo determine the best option f...
# ...

# %%
print(tasks_data_df[tasks_data_df['task_type']=='piqa'].iloc[1,7])
# Out:
# To create a snowy paper Christmas tree, cut three descending-sized circles with wavy edges from paper, make a triangular notch in each, roll them into cones secured with tape or glue, and stack them from largest to smallest, fixing them in place with glue.
