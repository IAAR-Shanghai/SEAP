# %%
# notebooks/1_data_exploration.ipynb

import os
import pandas as pd

# %%
# Define paths
root_data_dir = '../data/processed'

# %%
# Load a sample dataset (can explore others based on task)
tasks_data_df = pd.read_parquet(os.path.join(root_data_dir, 'prompts.parquet'))

# %%
# View the first few rows of the dataset
tasks_data_df[tasks_data_df['task_type']=='piqa'].head(5)
# Out:
#     task_type      task_format  \
# 160      piqa  multiple_choice
# 161      piqa  multiple_choice
# 162      piqa  multiple_choice
# 163      piqa  multiple_choice
# 164      piqa  multiple_choice
#
#                                               question label  \
# 160  Question: To remove a dandelion from the groun...     A
# 161  Question: How to Make a Snowy Paper Christmas ...     A
# 162  Question: What if I have a pimple that is too ...     B
# 163  Question: How do you clean Bamboo straws?\nOpt...     A
# 164  Question: How to flatten dough for pie crust.\...     A
#
#                                                   gold  \
# 160             Use your fingers to pick the dandelion
# 161  You can make a Snowy Paper Christmas Tree by f...
# 162  Place the pimple under hot water for 10 min. t...
# 163  They are washable and reusable. Use a jar of w...
# 164  Flatten dough with rolling pin until it's abou...
#
#                                                 corpus  \
# ...

# %%
# Check data types and missing values for each column
print(tasks_data_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   task_type         208 non-null    object
#  1   task_format       208 non-null    object
#  2   question          208 non-null    object
#  3   label             208 non-null    object
#  4   gold              208 non-null    object
#  5   corpus            208 non-null    object
#  6   rationale         208 non-null    object
#  7   knowledge         208 non-null    object
#  8   split             208 non-null    object
#  9   prompt_zero_shot  208 non-null    object
#  10  prompt_cot        208 non-null    object
#  11  prompt_icl        208 non-null    object
#  12  prompt_icl_cot    208 non-null    object
# dtypes: object(13)
# memory usage: 21.2+ KB
# None

# %%
print(tasks_data_df[tasks_data_df['task_type']=='hellaswag'].iloc[4,2])
# Out:
# Question: [header] How to prepare a child for dating [title] Have the talk with her, explaining what dating is. [step] The time to offer sound advice, and to let the young person know what to expect during a date is before the event. [title] Help the young person choose their wardrobe and make sure they have presentable clothing and accessories to wear during their date.
# Options:
# A) [step] You might go into details such as what is appropriate clothing for different activities, depending on how well the young person already deals with those things. [title] Talk to the young person about exactly where they will be going, and what they are going to do.
# B) [title] Take them to the beach, get a facial, carry a book, or take them out for a picnic at the beach, whatever is available for the young person. [step] Be prepared to be alone to prevent the teen from acting weird in the presence of other teens.
# ...

# %%
# 获取所有唯一的 task_type
unique_tasks = tasks_data_df['task_type'].unique()

# 为每个 task_type 输出 iloc[1, 5]
for task in unique_tasks:
    subset = tasks_data_df[tasks_data_df['task_type'] == task]
    if len(subset) > 1:  # 确保至少有两行才有 iloc[1]
        value = subset.iloc[1, 5]
        print(f"{task:<15} → {value}")
    else:
        print(f"{task:<15} → [⚠️ 不足两行，跳过]")
# Out:
# arc_challenge   → Which mixture contains ingredients that can be easily separated? fruit salad
# arc_easy        → Students are learning about the natural resources in Maryland. One group of students researches information about renewable natural resources in the state. The other group researches information about nonrenewable natural resources in the state. The resources the students investigate include plants, animals, soil, minerals, water, coal, and oil. Aluminum is a nonrenewable natural resource. Which of these methods of aluminum disposal is best for the environment? recycling it
# ...
