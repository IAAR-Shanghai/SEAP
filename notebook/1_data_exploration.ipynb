# %%
# notebooks/1_data_exploration.ipynb

import os
import pandas as pd

# %%
# Define paths
root_data_dir = '../data/processed'

# %%
# Load a sample dataset (can explore others based on task)
tasks_data_df = pd.read_parquet(os.path.join(root_data_dir, 'base.parquet'))

# %%
# View the first few rows of the dataset
tasks_data_df.head(3)
# Out:
#   task_type      task_format  \
# 0     arc_c  multiple_choice
# 1     arc_c  multiple_choice
# 2     arc_c  multiple_choice
#
#                                             question label  \
# 0  The day before the class is going to do a lab ...     B
# 1  Which mixture contains ingredients that can be...     B
# 2  In 2005, a team of scientists discovered a pho...     B
#
#                                         gold  \
# 0          to prevent injury to toes or feet
# 1                                fruit salad
# 2  The hydrothermal vent emits usable light.
#
#                                               corpus rationale knowledge  \
# 0  The day before the class is going to do a lab ...
# 1  Which mixture contains ingredients that can be...
# 2  In 2005, a team of scientists discovered a pho...
#
#    split
# 0  train
# 1  train
# 2  train

# %%
# Check data types and missing values for each column
print(tasks_data_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3235 entries, 0 to 3234
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   task_type    3235 non-null   object
#  1   task_format  3235 non-null   object
#  2   question     3235 non-null   object
#  3   label        3235 non-null   object
#  4   gold         3235 non-null   object
#  5   corpus       3235 non-null   object
#  6   rationale    3235 non-null   object
#  7   knowledge    3235 non-null   object
#  8   split        3235 non-null   object
# dtypes: object(9)
# memory usage: 227.6+ KB
# None

# %%
tasks_data_df[tasks_data_df['task_type']=='winogrande'].head(5)
# Out:
#        task_type      task_format  \
# 2979  winogrande  multiple_choice
# 2980  winogrande  multiple_choice
# 2981  winogrande  multiple_choice
# 2982  winogrande  multiple_choice
# 2983  winogrande  multiple_choice
#
#                                                question label         gold  \
# 2979  Mary traded the jelly beans for the chocolate ...     A  jelly beans
# 2980  I went to Thailand to have the treatment and n...     A    treatment
# 2981  Dennis felt a lot of guilt about lying but Bri...     B        Brian
# 2982  The draining discussion was followed by a live...     A   discussion
# 2983  Mark was in the drill of gathering proof that ...     A        proof
#
#                                                  corpus rationale knowledge  \
# 2979  Mary traded the jelly beans for the chocolate ...
# 2980  I went to Thailand to have the treatment and n...
# 2981  Dennis felt a lot of guilt about lying but Bri...
# 2982  The draining discussion was followed by a live...
# 2983  Mark was in the drill of gathering proof that ...
#
#       split
# 2979  train
# 2980  train
# 2981  train
# 2982  train
# 2983  train

# %%
print(tasks_data_df[tasks_data_df['task_type']=='winogrande'].iloc[4,5])
# Out:
# Mark was in the drill of gathering proof that proved his company engaged in Age Discrimination but the proof was not sufficient.
