# %%
# notebooks/1_data_exploration.ipynb

import os
import pandas as pd

# %%
# Define paths
root_data_dir = '../data/processed'

# %%
# Load a sample dataset (can explore others based on task)
tasks_data_df = pd.read_parquet(os.path.join(root_data_dir, 'prompts.parquet'))

# %%
# View the first few rows of the dataset
tasks_data_df[tasks_data_df['split']=='train'].head(3)
# Out:
#        task_type      task_format  \
# 0  arc_challenge  multiple_choice
# 1  arc_challenge  multiple_choice
# 2  arc_challenge  multiple_choice
#
#                                             question label  \
# 0  The day before the class is going to do a lab ...     B
# 1  Which mixture contains ingredients that can be...     B
# 2  In 2005, a team of scientists discovered a pho...     B
#
#                                         gold  \
# 0          to prevent injury to toes or feet
# 1                                fruit salad
# 2  The hydrothermal vent emits usable light.
#
#                                               corpus  \
# 0  The day before the class is going to do a lab ...
# 1  Which mixture contains ingredients that can be...
# 2  In 2005, a team of scientists discovered a pho...
#
#                                            rationale  \
# 0  The teacher's request for students not to wear...
# 1  Bread is a homogeneous mixture where ingredien...
# 2  Photosynthesis requires light to convert carbo...
#
#                                            knowledge  split  \
# 0  Closed shoes protect feet from injuries due to...  train
# 1  Mixtures with physically distinct components c...  train
# 2  Photosynthesis requires light energy. If photo...  train
#
#                                     prompt_zero_shot  \
# 0  Question: The day before the class is going to...
# 1  Question: Which mixture contains ingredients t...
# 2  Question: In 2005, a team of scientists discov...
#
#                                           prompt_cot  \
# 0  Question: The day before the class is going to...
# 1  Question: Which mixture contains ingredients t...
# 2  Question: In 2005, a team of scientists discov...
#
#                                           prompt_icl  \
# 0  Question: In 2005, a team of scientists discov...
# 1  Question: A sound is heard when you pluck a st...
# 2  Question: When performing an experiment for a ...
#
#                                       prompt_icl_cot
# 0  Question: In 2005, a team of scientists discov...
# 1  Question: A sound is heard when you pluck a st...
# 2  Question: When performing an experiment for a ...

# %%
# Check data types and missing values for each column
print(tasks_data_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   task_type         208 non-null    object
#  1   task_format       208 non-null    object
#  2   question          208 non-null    object
#  3   label             208 non-null    object
#  4   gold              208 non-null    object
#  5   corpus            208 non-null    object
#  6   rationale         208 non-null    object
#  7   knowledge         208 non-null    object
#  8   split             208 non-null    object
#  9   prompt_zero_shot  208 non-null    object
#  10  prompt_cot        208 non-null    object
#  11  prompt_icl        208 non-null    object
#  12  prompt_icl_cot    208 non-null    object
# dtypes: object(13)
# memory usage: 21.2+ KB
# None

# %%
print(tasks_data_df[tasks_data_df['task_type']=='mathqa'].iloc[4,6])
# Out:
# The man's rate in still water is the average of the downstream and upstream speeds, which is \((26 + 12) / 2 = 19\) kmph. The rate of the current is the difference between the downstream speed and the still water speed, which is \(26 - 19 = 7\) kmph. Therefore, the rate of the current is 7 kmph.
#
# Final Answer: D) 7.0
